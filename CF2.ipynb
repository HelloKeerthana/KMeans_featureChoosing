# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
cols = ["area", "perimeter", "compactness", "length", "width", "asymmetry", "groove", "class"]
df = pd.read_csv("C:\\Users\\satya\\OneDrive\\Desktop\\keerthana\\ML\\seeds_dataset.csv", names=cols, sep="\s+")
df.head()
# Out:
#     area  perimeter  compactness  length  width  asymmetry  groove  class
# 0  15.26      14.84       0.8710   5.763  3.312      2.221   5.220      1
# 1  14.88      14.57       0.8811   5.554  3.333      1.018   4.956      1
# 2  14.29      14.09       0.9050   5.291  3.337      2.699   4.825      1
# 3  13.84      13.94       0.8955   5.324  3.379      2.259   4.805      1
# 4  16.14      14.99       0.9034   5.658  3.562      1.355   5.175      1

# %% [markdown]
# checking all the graphs to see which one can do justice to create blobs and can be seperated efficiently

# %%
for i in range(len(cols)-1):
    for j in range(i+1, len(cols)-1):
        fig = plt.figure(figsize=(3,3))
        x_label = cols[i]
        y_label = cols[j]
        sns.scatterplot(x=x_label, y=y_label, data=df, hue='class')
        plt.legend()
        plt.show()

# %% [markdown]
# <h1><b>K-MEANS CLUSTERING</b></h1>

# %%
from sklearn.cluster import KMeans

# %%
df.columns
# Out:
# Index(['area', 'perimeter', 'compactness', 'length', 'width', 'asymmetry',
#        'groove', 'class'],
#       dtype='object')

# %%
x = "compactness"
y = "asymmetry"
X = df[[x,y]].values

# %%
kmeans = KMeans(n_clusters=3).fit(X)

# %%
clusters = kmeans.labels_

# %%
cluster_df = pd.DataFrame(np.hstack((X, clusters.reshape(-1,1))), columns=[x, y, "class"])

# %% [markdown]
# the one with KMeans clustering

# %%
fig = plt.figure(figsize=(4,4))
sns.scatterplot(x=x, y=y, hue='class', data=cluster_df)
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# the original data

# %%
fig = plt.figure(figsize=(4,4))
sns.scatterplot(x=x, y=y, hue='class', data=df)
plt.legend()
plt.plot()
# Out:
# []
